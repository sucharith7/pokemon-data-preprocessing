# %% [markdown]
# ### Pandas preprocessing with pokemon data
# a good guide for beginners

# %% [markdown]
# ### import pandas library

# %%
import pandas as pd

# %%
pokemon=pd.read_csv('pokemon.csv')

# %%
pokemon
# Out:
#                                              abilities  against_bug  \
# 0                          ['Overgrow', 'Chlorophyll']         1.00
# 1                          ['Overgrow', 'Chlorophyll']         1.00
# 2                          ['Overgrow', 'Chlorophyll']         1.00
# 3                             ['Blaze', 'Solar Power']         0.50
# 4                             ['Blaze', 'Solar Power']         0.50
# 5                             ['Blaze', 'Solar Power']         0.25
# 6                             ['Torrent', 'Rain Dish']         1.00
# 7                             ['Torrent', 'Rain Dish']         1.00
# 8                             ['Torrent', 'Rain Dish']         1.00
# 9                          ['Shield Dust', 'Run Away']         1.00
# 10                                       ['Shed Skin']         1.00
# 11                     ['Compoundeyes', 'Tinted Lens']         0.50
# 12                         ['Shield Dust', 'Run Away']         0.50
# ...

# %%
pokemon.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %%
#pokemon[['type1','type2']] for 2 coulmns
(pokemon['type1'][0:5])#for one column upto specific row
pokemon['type1']#for one column
# Out:
# 0         grass
# 1         grass
# 2         grass
# 3          fire
# 4          fire
# 5          fire
# 6         water
# 7         water
# 8         water
# 9           bug
# 10          bug
# 11          bug
# 12          bug
# 13          bug
# 14          bug
# 15       normal
# 16       normal
# 17       normal
# 18       normal
# 19       normal
# 20       normal
# 21       normal
# 22       poison
# 23       poison
# 24     electric
# 25     electric
# 26       ground
# 27       ground
# 28       poison
# 29       poison
#          ...
# 771      normal
# 772      normal
# 773        rock
# 774      normal
# 775        fire
# 776    electric
# 777       ghost
# 778       water
# 779      normal
# 780       ghost
# 781      dragon
# 782      dragon
# 783      dragon
# 784    electric
# 785     psychic
# 786       grass
# 787       water
# 788     psychic
# 789     psychic
# 790     psychic
# 791     psychic
# 792        rock
# 793         bug
# 794         bug
# ...

# %%
pokemon.iloc[1]# for any one row
#pokemon.iloc[1:4] for rows from  1to 4
# Out:
# abilities            ['Overgrow', 'Chlorophyll']
# against_bug                                    1
# against_dark                                   1
# against_dragon                                 1
# against_electric                             0.5
# against_fairy                                0.5
# against_fight                                0.5
# against_fire                                   2
# against_flying                                 2
# against_ghost                                  1
# against_grass                               0.25
# against_ground                                 1
# against_ice                                    2
# against_normal                                 1
# against_poison                                 1
# against_psychic                                2
# against_rock                                   1
# against_steel                                  1
# against_water                                0.5
# ...

# %%
#read speicific location (R,C)
pokemon.iloc[2,30]
# Out:
# 'Venusaur'

# %%
#for specific row
for index,row in pokemon.iterrows():
    print(index,row['type1'])
# Out:
# 0 grass
# 1 grass
# 2 grass
# 3 fire
# 4 fire
# 5 fire
# 6 water
# 7 water
# 8 water
# 9 bug
# 10 bug
# 11 bug
# 12 bug
# 13 bug
# 14 bug
# 15 normal
# 16 normal
# 17 normal
# 18 normal
# 19 normal
# 20 normal
# 21 normal
# 22 poison
# 23 poison
# 24 electric
# 25 electric
# 26 ground
# 27 ground
# 28 poison
# 29 poison
# 30 poison
# 31 poison
# 32 poison
# 33 poison
# 34 fairy
# 35 fairy
# 36 fire
# 37 fire
# 38 normal
# 39 normal
# 40 poison
# 41 poison
# 42 grass
# 43 grass
# 44 grass
# 45 bug
# 46 bug
# 47 bug
# 48 bug
# 49 ground
# 50 ground
# 51 normal
# 52 normal
# 53 water
# 54 water
# 55 fighting
# 56 fighting
# 57 fire
# 58 fire
# 59 water
# 60 water
# 61 water
# 62 psychic
# 63 psychic
# 64 psychic
# 65 fighting
# 66 fighting
# 67 fighting
# 68 grass
# 69 grass
# 70 grass
# 71 water
# 72 water
# 73 rock
# 74 rock
# 75 rock
# 76 fire
# 77 fire
# 78 water
# 79 water
# 80 electric
# 81 electric
# 82 normal
# 83 normal
# 84 normal
# 85 water
# 86 water
# 87 poison
# 88 poison
# ...

# %%
pokemon.loc[pokemon['type1']=='fire']
# Out:
#                                              abilities  against_bug  \
# 3                             ['Blaze', 'Solar Power']         0.50
# 4                             ['Blaze', 'Solar Power']         0.50
# 5                             ['Blaze', 'Solar Power']         0.25
# 36   ['Flash Fire', 'Drought', 'Snow Cloak', 'Snow ...         0.50
# 37   ['Flash Fire', 'Drought', 'Snow Cloak', 'Snow ...         0.50
# 57           ['Intimidate', 'Flash Fire', 'Justified']         0.50
# 58           ['Intimidate', 'Flash Fire', 'Justified']         0.50
# 76            ['Run Away', 'Flash Fire', 'Flame Body']         0.50
# 77            ['Run Away', 'Flash Fire', 'Flame Body']         0.50
# 125                     ['Flame Body', 'Vital Spirit']         0.50
# 135                             ['Flash Fire', 'Guts']         0.50
# 145                         ['Pressure', 'Flame Body']         0.25
# 154                            ['Blaze', 'Flash Fire']         0.50
# ...

# %%
pokemon.sort_values('type1',ascending=False)
#pokemon.sort_values(['type1','type2'],ascending=False)
#pokemon.sort_values(['type1','type2'],ascending=[1,0])
# Out:
#                                            abilities  against_bug  \
# 78         ['Oblivious', 'Own Tempo', 'Regenerator']          2.0
# 365                       ['Shell Armor', 'Rattled']          1.0
# 90         ['Shell Armor', 'Skill Link', 'Overcoat']          1.0
# 210     ['Poison Point', 'Swift Swim', 'Intimidate']          0.5
# 417                     ['Swift Swim', 'Water Veil']          1.0
# 97    ['Hyper Cutter', 'Shell Armor', 'Sheer Force']          1.0
# 98    ['Hyper Cutter', 'Shell Armor', 'Sheer Force']          1.0
# 489                                    ['Hydration']          1.0
# 366                     ['Swift Swim', 'Water Veil']          1.0
# 750                 ['Water Bubble', 'Water Absorb']          1.0
# 367                      ['Swift Swim', 'Hydration']          1.0
# 368            ['Swift Swim', 'Rock Head', 'Sturdy']          1.0
# 369                      ['Swift Swim', 'Hydration']          1.0
# ...

# %% [markdown]
# ##make changes in data

# %%
pokemon['Total']=pokemon['sp_attack']+pokemon['sp_defense']+pokemon['speed']

# %%
pokemon.head(4)
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  pokedex_number  sp_attack  sp_defense  \
# 0             2.0            1.0  ...               1         65          65
# 1             2.0            1.0  ...               2         80          80
# ...

# %%
#drop specific column
pokemon.drop(columns=['Total'])
# Out:
#                                              abilities  against_bug  \
# 0                          ['Overgrow', 'Chlorophyll']         1.00
# 1                          ['Overgrow', 'Chlorophyll']         1.00
# 2                          ['Overgrow', 'Chlorophyll']         1.00
# 3                             ['Blaze', 'Solar Power']         0.50
# 4                             ['Blaze', 'Solar Power']         0.50
# 5                             ['Blaze', 'Solar Power']         0.25
# 6                             ['Torrent', 'Rain Dish']         1.00
# 7                             ['Torrent', 'Rain Dish']         1.00
# 8                             ['Torrent', 'Rain Dish']         1.00
# 9                          ['Shield Dust', 'Run Away']         1.00
# 10                                       ['Shed Skin']         1.00
# 11                     ['Compoundeyes', 'Tinted Lens']         0.50
# 12                         ['Shield Dust', 'Run Away']         0.50
# ...

# %%
#add column
#pokemon['Total']=pokemon.iloc[:,4].sum(axis=0)

# %%
#pokemon.head()

# %%
#cols=list(pokemon.columns.values)
#pokemon=pokemon[cols[0:4]+[cols[-1]]+cols[4:12]]
#pokemon.head()
#pokemon=pokemon[['Total','type1','Type2']]

# %%
pokemon.to_csv('modified.csv',index=False)# save your data without index

# %% [markdown]
# filtering data

# %%
pokemon.loc[(pokemon['type1']=='grass')&(pokemon['type2']=='poison')]
# Out:
#                                           abilities  against_bug  \
# 0                       ['Overgrow', 'Chlorophyll']          1.0
# 1                       ['Overgrow', 'Chlorophyll']          1.0
# 2                       ['Overgrow', 'Chlorophyll']          1.0
# 42                      ['Chlorophyll', 'Run Away']          1.0
# 43                        ['Chlorophyll', 'Stench']          1.0
# 44                  ['Chlorophyll', 'Effect Spore']          1.0
# 68                      ['Chlorophyll', 'Gluttony']          1.0
# 69                      ['Chlorophyll', 'Gluttony']          1.0
# 70                      ['Chlorophyll', 'Gluttony']          1.0
# 314  ['Natural Cure', 'Poison Point', 'Leaf Guard']          1.0
# 405  ['Natural Cure', 'Poison Point', 'Leaf Guard']          1.0
# 406  ['Natural Cure', 'Poison Point', 'Technician']          1.0
# 589                 ['Effect Spore', 'Regenerator']          1.0
# ...

# %%
#pokemon.loc[pokemon['abilities'].str.contains('Chlorophyll')]
pokemon.loc[pokemon['abilities'].str.contains('Chlorophyll')] # ~ is used for to drop all the chloropyll from abilities
# Out:
#                                           abilities  against_bug  \
# 0                       ['Overgrow', 'Chlorophyll']          1.0
# 1                       ['Overgrow', 'Chlorophyll']          1.0
# 2                       ['Overgrow', 'Chlorophyll']          1.0
# 42                      ['Chlorophyll', 'Run Away']          1.0
# 43                        ['Chlorophyll', 'Stench']          1.0
# 44                  ['Chlorophyll', 'Effect Spore']          1.0
# 68                      ['Chlorophyll', 'Gluttony']          1.0
# 69                      ['Chlorophyll', 'Gluttony']          1.0
# 70                      ['Chlorophyll', 'Gluttony']          1.0
# 101                      ['Chlorophyll', 'Harvest']          4.0
# 102  ['Chlorophyll', 'Harvest', 'Frisk', 'Harvest']          4.0
# 113    ['Chlorophyll', 'Leaf Guard', 'Regenerator']          2.0
# 181                       ['Chlorophyll', 'Healer']          2.0
# ...

# %%
import re
pokemon.loc[pokemon['type1'].str.contains('fire|grass',regex=True)]
# Out:
#                                              abilities  against_bug  \
# 0                          ['Overgrow', 'Chlorophyll']         1.00
# 1                          ['Overgrow', 'Chlorophyll']         1.00
# 2                          ['Overgrow', 'Chlorophyll']         1.00
# 3                             ['Blaze', 'Solar Power']         0.50
# 4                             ['Blaze', 'Solar Power']         0.50
# 5                             ['Blaze', 'Solar Power']         0.25
# 36   ['Flash Fire', 'Drought', 'Snow Cloak', 'Snow ...         0.50
# 37   ['Flash Fire', 'Drought', 'Snow Cloak', 'Snow ...         0.50
# 42                         ['Chlorophyll', 'Run Away']         1.00
# 43                           ['Chlorophyll', 'Stench']         1.00
# 44                     ['Chlorophyll', 'Effect Spore']         1.00
# 57           ['Intimidate', 'Flash Fire', 'Justified']         0.50
# 58           ['Intimidate', 'Flash Fire', 'Justified']         0.50
# ...

# %% [markdown]
# conditional changes

# %%
pokemon.loc[pokemon['type1']=='fire','type1']='falmmer'#renamig fire as flammer in type 1 column

# %%
pokemon
# Out:
#                                              abilities  against_bug  \
# 0                          ['Overgrow', 'Chlorophyll']         1.00
# 1                          ['Overgrow', 'Chlorophyll']         1.00
# 2                          ['Overgrow', 'Chlorophyll']         1.00
# 3                             ['Blaze', 'Solar Power']         0.50
# 4                             ['Blaze', 'Solar Power']         0.50
# 5                             ['Blaze', 'Solar Power']         0.25
# 6                             ['Torrent', 'Rain Dish']         1.00
# 7                             ['Torrent', 'Rain Dish']         1.00
# 8                             ['Torrent', 'Rain Dish']         1.00
# 9                          ['Shield Dust', 'Run Away']         1.00
# 10                                       ['Shed Skin']         1.00
# 11                     ['Compoundeyes', 'Tinted Lens']         0.50
# 12                         ['Shield Dust', 'Run Away']         0.50
# ...

# %%
pokemon.loc[pokemon['Total']>100,['generation','is_legendary']]='TESt VALUE'
pokemon
# Out:
#                                              abilities  against_bug  \
# 0                          ['Overgrow', 'Chlorophyll']         1.00
# 1                          ['Overgrow', 'Chlorophyll']         1.00
# 2                          ['Overgrow', 'Chlorophyll']         1.00
# 3                             ['Blaze', 'Solar Power']         0.50
# 4                             ['Blaze', 'Solar Power']         0.50
# 5                             ['Blaze', 'Solar Power']         0.25
# 6                             ['Torrent', 'Rain Dish']         1.00
# 7                             ['Torrent', 'Rain Dish']         1.00
# 8                             ['Torrent', 'Rain Dish']         1.00
# 9                          ['Shield Dust', 'Run Away']         1.00
# 10                                       ['Shed Skin']         1.00
# 11                     ['Compoundeyes', 'Tinted Lens']         0.50
# 12                         ['Shield Dust', 'Run Away']         0.50
# ...
